# %%
from glob import glob
import audioFeatureExtraction, audioBasicIO
files = glob("/Users/Kerem/Dropbox/MarcosLemurData/wav/*.wav")[::3]
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# %matplotlib qt
import matplotlib.pylab as plt
plt.plot(range(10))
# for i, f in enumerate(files):
#     if not (i-1 % 1000):
#         print("{} out of {}".format(i, len(files)))
#     Fs, audio = audioBasicIO.readAudioFile(f)
#     data = audioFeatureExtraction.stEnergy(frame=audio)
#     plt.scatter(data, 1)

# %%
files[::3]
# Out:
# ['/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 90001.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 90004.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 90477.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 94858.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 94948.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 94969.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- 94977.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al12T259_pe_271.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al12T259_pe_627.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al12T259_pe_967.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al12T260_sa_279.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al18T341_pe_783.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al18T342_pe_1575.wav',
#  '/Users/Kerem/Dropbox/MarcosLemurData/wav/ALARM -- al18T345_pe_3547.wav',
# ...
